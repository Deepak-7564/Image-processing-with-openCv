# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("messi5.jpg", 0)
canny = cv2.Canny(img, 100, 200)

titles = ["image","canny"]
images = [img,canny]
for i in range(2):
    plt.subplot(1,2, i+1), plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])
    
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("sudoku.png", 0)
canny = cv2.Canny(img, 100, 200)

titles = ["image","canny"]
images = [img,canny]
for i in range(2):
    plt.subplot(1,2, i+1), plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])
    
plt.show()

# %%
import cv2 
import matplotlib.pyplot as plt
import numpy as np
img = cv2.imread("messi5.jpg", 0)
lap = cv2.Laplacian(img, cv2.CV_64F, ksize =3 )
lap = np.uint8(np.absolute(lap))
sobelx = cv2.Sobel(img, cv2.CV_64F, 1, 0)
sobely = cv2.Sobel(img, cv2.CV_64F, 0, 1)
canny = cv2.Canny(img,100, 200)

sobelx = np.uint8(np.absolute(sobelx))
sobely = np.uint8(np.absolute(sobely))

titles = ['image','lap','sobelx','sobely','canny']
images = [img,lap,sobelx,sobely,canny]
for i in range(5):
    plt.subplot(3,2,i+1), plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])
    
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def color(x):
    print(x)
img = cv2.imread("messi5.jpg", 0)
canny = cv2.Canny(img, 100, 200)
cv2.createTrackbar('Blue','image',0 , 255, color)

titles = ["image","canny"]
images = [img,canny]
for i in range(2):
    plt.subplot(1,2, i+1), plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])
    b = cv2.getTrackbarPos('Blue','image')
    
    img[:] = [b]
plt.show()

# %%
import numpy as np
import cv2 as cv

def color(x):
    print(x)
    
def canny(dx,dy):
    cv.canny(img,dx,dy)
    print(dx,dy)
    
#dx = 0
#dy =0 
    
img = cv.imread("messi5.jpg", 0)
#img = np.zeros((300,512,3), np.uint8)
cv.namedWindow("image")

#canny = cv.Canny(img, dx,dy)

cv.createTrackbar('dx','image',0 , 200, canny)
cv.createTrackbar('dy','image',0 , 200, canny)

while(1):
    cv.imshow('image',img)
    k = cv.waitKey(1) & 0xFF
    if k == 27:
        break
    
    b = cv.getTrackbarPos('dx','image')
    c = cv.getTrackbarPos('dy','image')
    
    canny[:] = [b,c]
    
cv.destroyAllWindows()

# %%
import cv2 as cv

def cannyf(thresh1 =0):
    thresh1 = cv.getTrackbarPos('thresh1','canny')
    thresh2 = cv.getTrackbarPos('thresh2','canny')
    edge = cv.Canny(img, thresh1, thresh2)
    cv.imshow('canny', edge)
    
if __name__ == '__main__':
#while(1):    
    original = cv.imread('messi5.jpg',1)
    img = original.copy()
    img = cv.GaussianBlur(img, (5,5), 0)
    
    cv.namedWindow('canny')
    
    thresh1 =100
    thresh2 = 1
    cv.createTrackbar('thresh1','canny',thresh1,255,cannyf)
    cv.createTrackbar('thresh2','canny',thresh2,255,cannyf)
    cannyf(1)
    cv.imshow('Frame',original)
    
    '''k = cv.waitKey(1) & 0xFF
    if k == 27:
        break'''
cv.waitKey(0)
    
cv.destroyAllWindows()
